# %%
## Generate Data
import numpy as np
import matplotlib.pyplot as plt
X = np.random.uniform(low=0,high=10,size=1000)
Y = np.sin(X)
plt.scatter(X,Y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=.3,shuffle=True)

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(1024, activation='relu',input_shape=(1,)),
  tf.keras.layers.Dropout(.5),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(.5),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(.5),
  tf.keras.layers.Dense(1)
])
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                                  patience=30,
                                                  mode='min')
model.compile(loss=tf.losses.MeanSquaredError(),
              optimizer=tf.optimizers.Adam())

history = model.fit(X_train,y_train,epochs=1000,callbacks=[early_stopping],validation_split=.3)
model.evaluate(X_test,y_test)
y_pred = model.predict(X_test)
plt.plot(history.epoch,history.history['loss'])
plt.plot(history.epoch,history.history['val_loss'])

plt.figure()
plt.scatter(X_test,y_pred,s=.1)
plt.scatter(X_test,y_test,s=.1)
# Out:
# Epoch 1/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5933
# Epoch 2/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5193
# Epoch 3/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4793
# Epoch 4/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4606
# Epoch 5/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4431
# Epoch 6/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4276
# Epoch 7/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4273
# Epoch 8/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4153
# Epoch 9/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3956
# Epoch 10/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3699
# Epoch 11/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3556
# Epoch 12/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3375
# Epoch 13/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3188
# Epoch 14/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3158
# Epoch 15/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3005
# Epoch 16/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2935
# Epoch 17/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2858
# Epoch 18/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2792
# Epoch 19/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2701
# Epoch 20/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2481
# Epoch 21/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2435
# Epoch 22/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2226
# Epoch 23/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2282
# Epoch 24/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1992
# Epoch 25/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2033
# Epoch 26/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1838
# Epoch 27/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1708
# Epoch 28/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1675
# Epoch 29/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1574
# Epoch 30/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1450
# Epoch 31/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1442
# Epoch 32/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1376
# Epoch 33/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1413
# Epoch 34/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1390
# Epoch 35/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1301
# Epoch 36/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1325
# Epoch 37/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1197
# Epoch 38/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1192
# Epoch 39/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1220
# Epoch 40/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1147
# Epoch 41/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1122
# Epoch 42/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1139
# Epoch 43/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1041
# Epoch 44/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1056
# Epoch 45/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1100
# Epoch 46/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1022
# Epoch 47/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.1029
# Epoch 48/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0910
# Epoch 49/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0955
# Epoch 50/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0982
# Epoch 51/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0921
# Epoch 52/1000
# 22/22 [==============================] - 0s 3ms/step - loss: 0.0896
# Epoch 53/1000
#  1/22 [>.............................] - ETA: 0s - loss: 0.1070
